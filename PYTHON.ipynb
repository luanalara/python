# %% [markdown]
# <a href="https://colab.research.google.com/github/luanalara/python/blob/main/PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**aula 1** 🌞 🎀 🧡

# %%
ano = "IX"
print(ano, " competição de programação dá Start")
# Out:
# IX  competição de programação dá Start

# %% [markdown]
# #**aula 2** ✈ 🏖 🥥

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2 * livro_ficcao + 5 * livro_infantil
pontos_totais = pontos_rodrigo + pontos_ana
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais de ana são {pontos_ana}")
print(f"Os pontos totais de ana e rodrigo são {pontos_totais}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais de ana são 46
# Os pontos totais de ana e rodrigo são 70

# %% [markdown]
# #**aula 3** ⛺ ⏰ ⛪

# %%
total_de_figurinhas = int(input("Digite o total de figurinhas: "))
numero_de_amigos = int(input("Digite o número de amigos: "))
figurinhas_amigo = total_de_figurinhas // (numero_de_amigos + 2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2999363842.py in <cell line: 0>()
# ----> 1 total_de_figurinhas = int(input("Digite o total de figurinhas: "))
#       2 numero_de_amigos = int(input("Digite o número de amigos: "))
#       3 figurinhas_amigo = total_de_figurinhas // (numero_de_amigos + 2)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %% [markdown]
# #**aula 4** ✨ 💐 🎟 tabuada

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)

# %% [markdown]
# #**aula 5** 🍾 📸 ⭐

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero / contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 8
# 8 x 1 = 8.0
# 8 x 2 = 4.0
# 8 x 3 = 2.6666666666666665
# 8 x 4 = 2.0
# 8 x 5 = 1.6
# 8 x 6 = 1.3333333333333333
# 8 x 7 = 1.1428571428571428
# 8 x 8 = 1.0
# 8 x 9 = 0.8888888888888888
# 8 x 10 = 0.8

# %% [markdown]
# #**aula 6** ✈ ☹ ❤ chatbot

# %%
print("olá, sou seu assistente virtual")
nome = input ("digite seu nome: ")
print(f"olá{nome}, em que posso ajudar?")
resposta = input("Você deseja falar sobre Python, javacript ou matemática: ").lower()
if resposta =="python":
  print(f"Ótimo, {nome},vamos falar sobre Python! \n Então, você que já manja de Python, também acha incrível como dá pra fazer quase qualquer coisa com ele")
elif resposta == "javascript":
  print(f"ótimo,{nome},vamos falar sobre Javascript \n JavaScript é a ponte entre a lógica e a criatividade — o código que transforma páginas estáticas em experiências vivas.")
elif resposta == "javascript":
  print(f"Otimo, {nome}, vamos falar sobre matemática! \n A matemática é a linguagem secreta do universo, onde cada número conta uma parte da história do mundo.")
else:
    print(f" Que pena, {nome}, não sei falar dess assunto")
# Out:
# olá, sou seu assistente virtual
# digite seu nome: luana
# oláluana, em que posso ajudar?

# %% [markdown]
# #**aula 7**: ⛸ ⛰ ⛄ listas

# %%
import random
dica = [
    "🌞 Todo recomeço é uma nova chance de fazer melhor — abrace a semana com coragem.",
    "🌤 Hoje é o dia perfeito para transformar esforço em progresso.",
    "🌿 Você já chegou até aqui — siga firme, o meio do caminho é sinal de força!",
    "🌅 Pequenos passos constantes te levam mais longe do que grandes saltos apressados.",
    "🌻 Orgulhe-se do que conquistou nesta semana — cada vitória merece ser celebrada!",
    "🌈 Relaxe, recarregue e lembre-se: cuidar de si também é parte do sucesso.",
    "☀️ Planeje com leveza, sonhe alto e prepare o coração para um novo ciclo cheio de possibilidades.",
]
while True:
  pedido = input("digite 'dica' para receber uma dica ou 'sair' para encerrar \n")

  if pedido == "dica":
    dica = random.choice(dicas) # escolhe uma dica aleatória sair
    print(f"dica: {dica} \n")
    break
  elif pedido == "sair":
    print ("até a proxima \n")
    break
  else:
    print("comando invalido \n")
    break
